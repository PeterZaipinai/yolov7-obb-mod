# %% [markdown]
# <a href="https://colab.research.google.com/github/PeterZaipinai/yolov7-obb-mod/blob/master/Training_YOLOV7_OBB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/3-14o/yolov7_obb
# Out:
# Cloning into 'yolov7_obb'...
# remote: Enumerating objects: 691, done.
# remote: Counting objects: 100% (691/691), done.
# remote: Compressing objects: 100% (338/338), done.
# remote: Total 691 (delta 393), reused 632 (delta 343), pack-reused 0
# Receiving objects: 100% (691/691), 46.65 MiB | 15.32 MiB/s, done.
# Resolving deltas: 100% (393/393), done.

# %%
# %cd /content/yolov7_obb/
# Out:
# /content/yolov7_obb

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip3 install torch==1.10.1+cu113 torchvision==0.11.2+cu113 torchaudio==0.10.1+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/cu113/torch_stable.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 GB 942.3 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 46.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 4.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1+cu116
#     Uninstalling torch-1.13.1+cu116:
#       Successfully uninstalled torch-1.13.1+cu116
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.14.1+cu116
#     Uninstalling torchvision-0.14.1+cu116:
#       Successfully uninstalled torchvision-0.14.1+cu116
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.13.1+cu116
#     Uninstalling torchaudio-0.13.1+cu116:
#       Successfully uninstalled torchaudio-0.13.1+cu116
# ...

# %%
# !nvcc -V
# !python
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0
# Python 3.9.16 (main, Dec  7 2022, 01:11:51)
# [GCC 9.4.0] on linux
# Type "help", "copyright", "credits" or "license" for more information.
# >>>
# KeyboardInterrupt
# >>>
# KeyboardInterrupt
# >>> ^C

# %%
! pip uninstall torchtext -y
! pip install torch==1.10.1+cu113 torchvision==0.11.2+cu113 torchaudio==0.10.1+cu113 torchtext
# Out:
# WARNING: Skipping torchtext as it is not installed.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached torchtext-0.15.1-cp39-cp39-manylinux1_x86_64.whl (2.0 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 40.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 72.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 71.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 70.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 69.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 74.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 81.7 MB/s eta 0:00:00
# ...

# %%
# %cd utils/nms_rotated
# !python setup.py develop
# Out:
# /content/yolov7_obb/utils/nms_rotated
# running develop
# /usr/local/lib/python3.9/dist-packages/setuptools/command/easy_install.py:144: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# running egg_info
# creating nms_rotated.egg-info
# writing nms_rotated.egg-info/PKG-INFO
# writing dependency_links to nms_rotated.egg-info/dependency_links.txt
# writing top-level names to nms_rotated.egg-info/top_level.txt
# writing manifest file 'nms_rotated.egg-info/SOURCES.txt'
# /usr/local/lib/python3.9/dist-packages/torch/utils/cpp_extension.py:381: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
# ...

# %%
# !unzip "/content/drive/MyDrive/DOTA_reduced_rate1.0_split1024_gap200.zip" -d "/content"
!7z x /content/drive/MyDrive/DOTA_rate1.0_split1024_gap200.7z -o/content
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,8 CPUs Intel(R) Xeon(R) CPU @ 2.00GHz (50653),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 23192543202 bytes (22 GiB)
#
# Extracting archive: /content/drive/MyDrive/DOTA_rate1.0_split1024_gap200.7z
# --
# Path = /content/drive/MyDrive/DOTA_rate1.0_split1024_gap200.7z
# Type = 7z
# Physical Size = 23192543202
# Headers Size = 513377
# Method = LZMA2:24
# Solid = +
# Blocks = 7
#
# Everything is Ok
#
# Folders: 9
# Files: 63143
# Size:       29758661937
# Compressed: 23192543202

# %% [markdown]
# Exclude cache files on dataset

# %%
# !cp "/content/drive/MyDrive/yolov7_training.pt" -d "/content/yolov7_obb"

# %%
# !cp "/content/drive/MyDrive/runs/train/yolov7-obb17_deploy/weights/yolov7_obb2.pt" -d "/content/yolov7_obb"

# %%
cd ..
# Out:
# /content/yolov7_obb

# %% [markdown]
# Some options to train: --cache-images --v5-metric

# %% [markdown]
# Adjust hyp.yalm to better training

# %%
# !python ./train.py --workers 8 --device 0 --batch-size 18 --epoch 300 --img 1024 1024 --data ./data/dotav1_poly1drive.yaml --hyp ./data/hyp.scratch.dota.yaml --cfg ./cfg/training/yolov7_DOTAv1.yaml --name yolov7-obb --weights ./best.pt --project ../drive/MyDrive/runs/train --cache-images
# Out:
# YOLOR 🚀 ba9462e torch 1.10.1+cu113 CUDA:0 (A100-SXM4-40GB, 40536.1875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=18, bbox_interval=-1, bucket='', cache_images=True, cfg='./cfg/training/yolov7_DOTAv1.yaml', data='./data/dotav1_poly1drive.yaml', device='0', entity=None, epochs=300, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='./data/hyp.scratch.dota.yaml', image_weights=False, img_size=[1024, 1024], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='yolov7-obb', noautoanchor=False, nosave=False, notest=False, project='../drive/MyDrive/runs/train', quad=False, rect=False, resume=False, save_dir='../drive/MyDrive/runs/train/yolov7-obb20', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=18, upload_dataset=False, v5_metric=False, weights='./best.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir ../drive/MyDrive/runs/train', view at http://localhost:6006/
# ...

# %% [markdown]
# Testing time

# %%
# !python ./train.py --workers 8 --device 0 --batch-size 18 --epoch 300 --img 1024 1024 --data ./data/dotav1_poly1drive.yaml --hyp ./data/hyp.scratch.dota.yaml --cfg ./cfg/training/yolov7_DOTAv1.yaml --name yolov7-obb --weights ./yolov7_obb.pt --project ../drive/MyDrive/runs/train
# Out:
# YOLOR 🚀 915df7b torch 1.10.1+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=18, bbox_interval=-1, bucket='', cache_images=False, cfg='./cfg/training/yolov7_DOTAv1.yaml', data='./data/dotav1_poly1drive.yaml', device='0', entity=None, epochs=300, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='./data/hyp.scratch.dota.yaml', image_weights=False, img_size=[1024, 1024], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='yolov7-obb', noautoanchor=False, nosave=False, notest=False, project='../drive/MyDrive/runs/train', quad=False, rect=False, resume=False, save_dir='../drive/MyDrive/runs/train/yolov7-obb23', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=18, upload_dataset=False, v5_metric=False, weights='./yolov7_obb.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir ../drive/MyDrive/runs/train', view at http://localhost:6006/
# ...

# %% [markdown]
# --v5-metric --task speed --save-json --save-conf --save-txt --save-hybrid

# %%
# !python ./test.py  --device 0 --batch-size 8 --img 1024 --data ./data/dotav1_poly1drive.yaml --name yolov7-obb --weights ./yolov7_obb2.pt --project ../drive/MyDrive/runs/test --v5-metric --task speed
# Out:
# Namespace(augment=False, batch_size=8, conf_thres=0.001, data='./data/dotav1_poly1drive.yaml', device='0', exist_ok=False, img_size=1024, iou_thres=0.65, name='yolov7-obb', no_trace=False, project='../drive/MyDrive/runs/test', save_conf=False, save_hybrid=False, save_json=False, save_txt=False, single_cls=False, task='speed', v5_metric=True, verbose=False, weights=['./yolov7_obb2.pt'])
# YOLOR 🚀 915df7b torch 1.10.1+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 306 layers, 37530001 parameters, 37530001 gradients, 106.5 GFLOPS
# ...

# %%
# !nvidia-smi
# Out:
# Fri Nov 11 19:44:28 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # Comparing with yolov5-obb

# %%
cd ..
# Out:
# /content

# %%
# !git clone https://github.com/hukaixuan19970627/yolov5_obb.git
# %cd yolov5_obb
# Out:
# Cloning into 'yolov5_obb'...
# remote: Enumerating objects: 704, done.
# remote: Counting objects: 100% (229/229), done.
# remote: Compressing objects: 100% (135/135), done.
# remote: Total 704 (delta 157), reused 141 (delta 91), pack-reused 475
# Receiving objects: 100% (704/704), 18.23 MiB | 15.15 MiB/s, done.
# Resolving deltas: 100% (292/292), done.
# /content/yolov5_obb

# %%
# !pip install -r requirements.txt
# %cd utils/nms_rotated
# !python setup.py develop

# %%
# !cp "/content/drive/MyDrive/runs/train/yolov5/best.pt" -d "/content/yolov5_obb"

# %%
cd ..
# Out:
# /content/yolov5_obb

# %%
# !python ./train.py  --device 0 --batch-size 8 --img 1024 --data ./data/dotav1_poly1drive.yaml --name yolov5-obb --weights ./yolov5m.pt --project ../drive/MyDrive/runs/train

# %% [markdown]
# --save-json --save-conf --save-txt --save-hybrid --task speed

# %%
# !python ./val.py  --device 0 --img 1024 --data ./data/dotav1_poly1drive.yaml --name yolov5-obb --weights ./best.pt --project ../drive/MyDrive/runs/test --task speed
# Out:
# val: data=./data/dotav1_poly1drive.yaml, weights=['./best.pt'], batch_size=8, imgsz=1024, conf_thres=0.01, iou_thres=0.4, task=speed, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=../drive/MyDrive/runs/test, name=yolov5-obb, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 b00c3f2 torch 1.10.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model Summary: 290 layers, 21640929 parameters, 0 gradients, 50.4 GFLOPs
# val: Scanning '../DOTA_rate1.0_split1024_gap200/validation/labelTxt.cache' images and labels... 5297 found, 0 missing, 1890 empty, 0 corrupted: 100% 5297/5297 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R  HBBmAP@.5  HBBmAP@.5:.95: 100% 663/663 [02:06<00:00,  5.24it/s]
#                  all       5297     123762      0.803      0.671      0.753      0.484
# ...
